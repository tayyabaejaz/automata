# %% [markdown]
# <a href="https://colab.research.google.com/github/tayyabaejaz/automata/blob/main/AUTOMATA_assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DFA 1:Accepts all the languages instead of  those with length two**

# %% [markdown]
# **DIAGRAM**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **TRANSITION TABLE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd


#for states
#initial state
def state1(str):
  if (str == '0'):  
        dfa = 3
        return dfa 
  elif (str == '1'):  
        dfa = 1
        return dfa 
  else:  
        print("Invalid alphabet in the string")
  

def state2(str):
  if (str == '0'):  
        dfa = 1
        return dfa 
  elif (str == '1'):  
        dfa = 2
        return dfa 
  else:  
         print("Invalid alphabet in the string")
  
def state3(str):
  if (str == '0'):  
        dfa = 2
        return dfa 
  elif (str == '1'):  
        dfa = 2
        return dfa 
  else:  
         print("Invalid alphabet in the string")

def state4(str):
  if (str == '0'):  
        dfa = 4
        return dfa 
  elif (str == '1'):  
        dfa = 3
        return dfa 
  else:  
         print("Invalid alphabet in the string")


def state5(str):
  if (str == '0'):  
        dfa = 4
        return dfa 
  elif (str == '1'):  
        dfa = 4
        return dfa 
  else:  
         print("Invalid alphabet in the string")


        
#for string acceptance
def string_acceptance(string):
  l = len(string)   
#dfa defines the state
  dfa = 0 #start state
  for i in range(l):   
    if (dfa == 0):   
          dfa=state1(string[i])
      
    elif (dfa == 1):   
           dfa=state2(string[i])
    
    elif (dfa == 2):   
           dfa=state3(string[i])
    
    elif (dfa == 3):   
           dfa=state4(string[i])

    elif (dfa == 4):   
           dfa=state5(string[i])
    else:
      return 0
  if(dfa==2): #string acceptance
    print("string reached final state")
    return 1
  elif (dfa==4):
    print("string reached final state")
    return 1
  else:
    print("string did not reach final state")
    return 0
    



#main
states=[0,1]
initial_state=0
final_state=0


#loading csv file
# df=pd.read_csv("stringfile.csv")
# for index, row in df.iterrows():
#     str=print(row)
#string input
string=input("enter a string :")
print(string)
if(string_acceptance(string)):
      print("String Accepted")
else:
      print("Invalid String")
# file1 = open('stringfile.txt', 'r')
# lines = file1.readlines()
# for i in lines:
#     print(lines[i])
# Out:
# enter a string :010101
# 010101
# string reached final state
# String Accepted

# %% [markdown]
# **DFA2:**

# %% [markdown]
# **DIAGRAM**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **TRANSITION TABLE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd


#for states
#initial state
def state1(str):
  if (str == '0'):  
        dfa = 1
        return dfa 
  elif (str == '1'):  
        dfa = 3
        return dfa 
  else:  
        print("Invalid alphabet in the string")
  

def state2(str):
  if (str == '0'):  
        dfa = 0
        return dfa 
  elif (str == '1'):  
        dfa = 2
        return dfa 
  else:  
         print("Invalid alphabet in the string")
  
def state3(str):
  if (str == '0'):  
        dfa = 3
        return dfa 
  elif (str == '1'):  
        dfa = 1
        return dfa 
  else:  
         print("Invalid alphabet in the string")

def state4(str):
  if (str == '0'):  
        dfa = 2
        return dfa 
  elif (str == '1'):  
        dfa = 0
        return dfa 
  else:  
         print("Invalid alphabet in the string")

        
#for string acceptance
def string_acceptance(string):
  l = len(string)   
#dfa defines the state
  dfa = 0 #start state
  for i in range(l):   
    if (dfa == 0):   
          dfa=state1(string[i])
      
    elif (dfa == 1):   
           dfa=state2(string[i])
    
    elif (dfa == 2):   
           dfa=state3(string[i])
    
    elif (dfa == 3):   
           dfa=state4(string[i])

    else:
      return 0
  if(dfa==0): #string acceptance
    print("string reached final state")
    return 1
  else:
    print("string did not reach final state")
    return 0
    



#main
states=[0,1]
initial_state=0
final_state=0


#loading csv file
# df=pd.read_csv("stringfile.csv")
# for index, row in df.iterrows():
#     str=print(row)
#string input
string=input("enter a string :")
print(string)
if(string_acceptance(string)):
      print("String Accepted")
else:
      print("Invalid String")
# file1 = open('stringfile.txt', 'r')
# lines = file1.readlines()
# for i in lines:
#     print(lines[i])
# Out:
# enter a string :11
# 11
# string reached final state
# String Accepted

# %% [markdown]
# **DFA 3**

# %% [markdown]
# **DIAGRAM**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **TRANSITION TABLE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd


#for states
#initial state
def state1(str):
  if (str == 'a'):  
        dfa = 2
        return dfa 
  elif (str == 'b'):  
        dfa = 2
        return dfa
  elif (str == 'c'):  
        dfa = 1
        return dfa 
  else:  
        print("Invalid alphabet in the string")
  

def state2(str):
  if (str == 'a'):  
        dfa = 3
        return dfa 
  elif (str == 'b'):  
        dfa = 2
        return dfa 
  elif (str == 'c'):  
        dfa = 2
        return dfa 
  else:  
         print("Invalid alphabet in the string")
  
def state3(str):
  if (str == 'a'):  
        dfa = 3
        return dfa 
  elif (str == 'b'):  
        dfa = 3
        return dfa 
  elif (str == 'c'):  
        dfa = 3
        return dfa 
  else:  
         print("Invalid alphabet in the string")

def state4(str):
  if (str == 'a'):  
        dfa = 3
        return dfa 
  elif (str == 'b'):  
        dfa = 3
        return dfa 
  elif (str == 'c'):  
        dfa = 3
        return dfa 
  else:  
         print("Invalid alphabet in the string")

        
#for string acceptance
def string_acceptance(string):
  l = len(string)   
#dfa defines the state
  dfa = 0 #start state
  for i in range(l):   
    if (dfa == 0):   
          dfa=state1(string[i])
      
    elif (dfa == 1):   
           dfa=state2(string[i])
    
    elif (dfa == 2):   
           dfa=state3(string[i])
    
    elif (dfa == 3):   
           dfa=state4(string[i])

    else:
      return 0
  if(dfa==2): #string acceptance
    print("string reached final state")
    return 1
  else:
    print("string did not reach final state")
    return 0
    



#main
states=[0,1]
initial_state=0
final_state=0


#loading csv file
# df=pd.read_csv("stringfile.csv")
# for index, row in df.iterrows():
#     str=print(row)
#string input
string=input("enter a string :")
print(string)
if(string_acceptance(string)):
      print("String Accepted")
else:
      print("Invalid String")
# file1 = open('stringfile.txt', 'r')
# lines = file1.readlines()
# for i in lines:
#     print(lines[i])
# Out:
# enter a string :abcd
# abcd
# Invalid alphabet in the string
# string did not reach final state
# Invalid String
